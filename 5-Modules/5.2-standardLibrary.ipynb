# %% [markdown]
# ### Standard library Overview
#
# #### Python Standard Libray is a vast collection of modules and packages that come bundled with python, providing a wide range of functionalities out of the box. here's an overview of the most commonly used modules and packages in the python standard library.

# %%
print("hello")
# Out:
# hello

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random

print(random.randint(1,10))
print(random.choice(['apple','banana','orange','cherry','grapes','gauva']))
# Out:
# 10
# apple

# %%
#File and Directory access

import os
print(os.getcwd())   ## check location of the file in which we are crunntly working
# Out:
# c:\Users\itssa\OneDrive\Desktop\udemy\Python\5-Modules

# %%
os.mkdir('test_dir')          ## make new file in the same location

# %%
# High level operation on files and collection on files

import shutil
shutil.copyfile('source.txt','location.txt')
# Out:
# 'location.txt'

# %%
import shutil
shutil.copyfile('location.txt','final.txt')
# Out:
# 'final.txt'

# %%
#Data Seralization

import json

data ={'name':'sachin','age':21}
json_str = json.dumps(data)

print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "sachin", "age": 21}
# <class 'str'>
# {'name': 'sachin', 'age': 21}
# <class 'dict'>

# %%
import csv

with open('exaple.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['sachin',21])

with open('exaple.csv',mode='r')as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['sachin', '21']

# %%
## datatime

from datetime import datetime,timedelta

now = datetime.now()
print(now)

yesterday =now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-22 17:53:08.785625
# 2026-06-21 17:53:08.785625

# %%
# time

import time 
print(time.time())
time.sleep(4)
print(time.time())
# Out:
# 1782131109.6182168
# 1782131113.6198373

# %%
#Regular expression 

import re

pattern =r'\d+'
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
