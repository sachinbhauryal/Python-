# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### Importing Modules in Python : Modules and packages
#
# ##### In python modules and packages help organise and reuse code.

# %%
import math 
math.sqrt(23)
# Out:
# 4.795831523312719

# %%
from math import * 
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy

# %%
import numpy as np
np.array([1,2,3,4])

# %%
from package.m import add
add(3,2)
