# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
num1 = input("enter the number:")
print(num1)
# Out:
# 23

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num1 = int(input("Enter the number: "))
if num1 > 0:
    print("Positive")
elif num1 < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input("enter the First number:"))
num2 = int(input("enter the Second number:"))   
num3 = int (input("enter the third number :"))

print("Num1 :",num1)
print("Num2 :",num2)
print("Num3 :",num3)

if(num1 > num2) and (num1 >num3):
    print(num1, "is the greatest number.")
elif(num2 > num1) and (num2 > num3):
    print(num2, "is the gratest number.")
else: 
    print(num3," is the gratest number.")
# Out:
# Num1 : 43
# Num2 : 72
# Num3 : 93
# 93  is the gratest number

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
fact = 1 
num = int (input("Enter the no whose factorial you want to find: "))
if num < 0:
    print("sorry, negative number factorail does not exist.")
elif num == 0:
    print("The factorial of 0 is 1.")
else:
    for i in range(1,num+1):
        fact = fact *i 
        print("the factorial of ",num, "is",fact)
# Out:
# the factorial of  5 is 1
# the factorial of  5 is 2
# the factorial of  5 is 6
# the factorial of  5 is 24
# the factorial of  5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here 
a = 3
b = 4.3
c = "hello world"
d = True

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 3 <class 'int'>
# 4.3 <class 'float'>
# hello world <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 10
b = 20 
print(f"before swapping: a ={a}, b = {b}")

a = b
b = a 
print(f"after swapping: a ={a}, b = {b}")
# Out:
# before swapping: a =10, b = 20
# after swapping: a =20, b = 20

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input("enter the temperature in Celsius :"))
fahrenheit = (celsius *9/5) + 32
print(f"{celsius}°C  is equal to : {fahrenheit}°F ")
# Out:
# 24.0°C  is equal to : 75.2°F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "hello"
str2 = "World"

print(str1 + ' ' +str2)
# Out:
# hello World

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = 32

if isinstance(var,float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")
# Out:
# 32 is not a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 20
b = 2

print(f"Addition of {a} + {b} = {a+b}")
print(f"Subtraction of {a} - {b} = {a-b}")
print(f"Multiplication of {a} * {b} = {a*b}")
print(f"Divison of {a} / {b} = {a/b}")
# Out:
# Addition of 20 + 2 = 22
# Subtraction of 20 - 2 = 18
# Multiplication of 20 * 2 = 40
# Divison of 20 / 2 = 10.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 20
b = 2

print(f"Equal to  {a} == {b} = {a==b}")
print(f"Not Equal to {a} != {b} = {a!=b}")
print(f"Greater than {a} > {b} = {a>b}")
print(f"less than {a} < {b} = {a<b}")
# Out:
# Equal to  20 == 2 = False
# Not Equal to 20  !=2 = True
# Greater than 20 > 2 = True
# less than 20 < 2 = False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False

print(f"AND operator  {a} AND {b} = {a and b}")
print(f"OR operator  {a} OR {b} = {a or b}")
print(f"NOT operator   NOT {a} = { not a}")
# Out:
# AND operator  True AND False = False
# OR operator  True OR False = True
# NOT operator   NOT True = False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("enter the number whose square you want :"))
print(num**2)
# Out:
# 16

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("enter the number"))
if(num % 2 == 0):
    print(f"{num} is Even")
else:
    print(f"{num} is Odd")
# Out:
# 34 is Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
sum = 0 
n = int(input("enter the no of natural number"))
for i in range(1 ,n+1):
    sum = sum + i
    print(f"sum of {i} natural number is:{sum}")
# Out:
# sum of 1 natural number is:1
# sum of 2 natural number is:3
# sum of 3 natural number is:6
# sum of 4 natural number is:10
# sum of 5 natural number is:15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("enter the year:"))
if((year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)):
    print(f"{year} is a leap year.")
else:
    print(f"year is not a leap year.")
# Out:
# 2024 is a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = input("enter the string")
reversedString = str[::-1]
print(f"The reversed string is : {reversedString}")
# Out:
# The reversed string is :  nihcas si siht

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str = input("enter the string")
if(str == str[::-1]):
    print("string is Palindrome")
else:
    print("string is not Palindrome")
# Out:
# string is Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
number =  [int(x) for x in input("Enter the number seperated by spaces").split()]
number.sort()
print(f"sorted list:{number}")
# Out:
# sorted list:[4, 7, 15, 45, 46, 56, 99]
