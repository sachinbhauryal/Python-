# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## 5 Numbers summary  and Box Plot

# %%
# Mininmum, Maximum, Median, Q1, Q3, IQR

import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,9,90,87,67,54,45,98,99,67,74]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks1=[-70,-97,45,32,56,75,89,54,32,9,90,87,67,54,45,98,99,67,74,100,233,300]

# %%
sns.boxplot(lst_marks1)
# Out:
# <Axes: >
